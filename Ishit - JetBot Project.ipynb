# %%
import ipywidgets as widgets
from IPython.display import display
import ipywidgets
# Out:
# Running cells with 'c:\Users\ishit\AppData\Local\Microsoft\WindowsApps\python3.10.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/ishit/AppData/Local/Microsoft/WindowsApps/python3.10.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
import time
from jetbot import Robot
robot = Robot()
# Out:
# Error loading module `ublox_gps`: No module named 'serial'

# %%
def draw(a):
    for i in str(a):
        if i=='A':
            draw_A()
        elif i=='B':
            draw_B()
        elif i=='C':
            draw_C()
        elif i=='D':
            draw_D()
        elif i=='E':
            draw_E()
        elif i=='F':
            draw_F()
        elif i=='G':
            draw_G()
        elif i=='H':
            draw_H()
        elif i=='I':
            draw_I()
        elif i=='J':
            draw_J()
        elif i=='K':
            draw_K()
        elif i=='L':
            draw_L()
        elif i=='M':
            draw_M()
        elif i=='N':
            draw_N()
        elif i=='O':
            draw_O()
        elif i=='P':
            draw_P()
        elif i=='Q':
            draw_Q()
        elif i=='R':
            draw_R()
        elif i=='S':
            draw_S()
        elif i=='T':
            draw_T()
        elif i=='U':
            draw_U()
        elif i=='V':
            draw_V()
        elif i=='W':
            draw_W()
        elif i=='X':
            draw_X()
        elif i=='Y':
            draw_Y()
        elif i=='Z':
            draw_Z()
        elif i=='0':
            draw_0()
        elif i=='1':
            draw_1()
        elif i=='2':
            draw_2()
        elif i=='3':
            draw_3()
        elif i=='4':
            draw_4()
        elif i=='5':
            draw_5()
        elif i=='6':
            draw_6()
        elif i=='7':
            draw_7()
        elif i=='8':
            draw_8()
        elif i=='9':
            draw_9()
        elif i==' ':
            draw_SPACE()

# %%
######FINAL
def f():
    robot.set_motors(0.3, 0.3)
    time.sleep(0.65)
    robot.stop()
    time.sleep(0.4)
def b():
    robot.set_motors(-0.3, -0.3)
    time.sleep(0.65)
    robot.stop()
    time.sleep(0.4)
def d():
    robot.set_motors(0.3, 0.3)
    time.sleep(0.9)
    robot.stop()
    time.sleep(0.4)
def r():
    robot.set_motors(0.3, -0.30)
    time.sleep(0.1265)
    robot.stop()
    time.sleep(0.4)
def r2():
    robot.set_motors(0.3, -0.30)
    time.sleep(0.236)
    robot.stop()
    time.sleep(0.4)
def r4():
    robot.set_motors(0.3, -0.30)
    time.sleep(0.5125)
    robot.stop()
    time.sleep(0.4)
def l():
    robot.set_motors(-0.3, 0.30)
    time.sleep(0.127)
    robot.stop()
    time.sleep(0.4)
def l2():
    robot.set_motors(-0.3, 0.30)
    time.sleep(0.275)
    robot.stop()
    time.sleep(0.4)

# %%
########FINAL
def draw_A():
    f()
    r()
    d()
    r2()
    d()
    l()
    b()
    b()
    f()
    f()
    r2()
    f()
    l2()
    f()
    l2()
def draw_B():
    f()
    f()
    r2()
    f()
    f()
    r2()
    r()
    d()
    l2()
    d()
    l()
    b()
    b()
    f()
    f()
    f()
    l2()
def draw_C():
    f()
    f()
    r2()
    f()
    f()
    b()
    b()
    r2()
    f()
    f()
    l2()
    f()
    f()
    f()
    r4()
    d()
    d()
    l()
    f()
    l2()
def draw_Y():
    r2()
    f()
    l2()
    f()
    l()
    d()
    r4()
    d()
    l2()
    d()
    r4()
    d()
    l()
    f()
    l2()
    f()
    f()
    l2()
def draw_Z():
    r()
    d()
    d()
    r()
    b()
    b()
    f()
    f()
    r2()
    r()
    d()
    d()
    r()
    b()
    b()
    b()
    r2()
def draw_0():
    f()
    f()
    r2()
    f()
    r2()
    f()
    f()
    l2()
    b()
    f()
    f()
    l2()
def draw_1():
    f()
    f()
    b()
    b()
    r2()
    f()
    l2()
def draw_2():
    f()
    r2()
    f()
    l2()
    f()
    l2()
    f()
    b()
    l2()
    f()
    r2()
    f()
    l2()
    f()
    l2()
    f()
    f()
    l2()
def draw_3():
    r2()
    f()
    l2()
    f()
    f()
    l2()
    f()
    b()
    l2()
    f()
    r2()
    f()
    b()
    l2()
    f()
    l2()
    f()
    l2()
def draw_4():
    r2()
    f()
    l2()
    f()
    f()
    b()
    l2()
    f()
    r2()
    f()
    b()
    r2()
    f()
    r2()
    f()
    l2()
    f()
    l2()
def draw_5():
    r2()
    f()
    l2()
    f()
    l2()
    f()
    r2()
    f()
    r2()
    f()
    b()
    r2()
    f()
    l2()
    f()
    r2()
    f()
    l2()
    f()
    l2()
def draw_6():
    pass
def draw_7():
    r()
    d()
    d()
    l()
    l2()
    f()
    f()
    b()
    b()
    l()
    d()
    d()
    r()
    b()
    b()
    b()
    r2()
def draw_8():
    pass
def draw_9():
    r2()
    f()
    l2()
    f()
    f()
    l2()
    f()
    l2()
    f()
    l2()
    f()
    r2()
    f()
    l2()
    f()
    l2()
def draw_SPACE():
    r2()
    f()
    f()
    f()
    l2()

# %%
button_A = widgets.Button(description='A')
button_B = widgets.Button(description='B')
button_C = widgets.Button(description='C')
button_D = widgets.Button(description='D')
button_E = widgets.Button(description='E')
button_F = widgets.Button(description='F')
button_G = widgets.Button(description='G')
button_H = widgets.Button(description='H')
button_I = widgets.Button(description='I')
button_J = widgets.Button(description='J')
button_K = widgets.Button(description='K')
button_L = widgets.Button(description='L')
button_M = widgets.Button(description='M')
button_N = widgets.Button(description='N')
button_O = widgets.Button(description='O')
button_P = widgets.Button(description='P')
button_Q = widgets.Button(description='Q', disabled = True)
button_R = widgets.Button(description='R')
button_S = widgets.Button(description='S')
button_T = widgets.Button(description='T')
button_U = widgets.Button(description='U')
button_V = widgets.Button(description='V', disabled = True)
button_W = widgets.Button(description='W')
button_X = widgets.Button(description='X')
button_Y = widgets.Button(description='Y')
button_Z = widgets.Button(description='Z')
button_SPACE = widgets.Button(description='[__]')
button_0 = widgets.Button(description='0')
button_1 = widgets.Button(description='1')
button_2 = widgets.Button(description='2')
button_3 = widgets.Button(description='3')
button_4 = widgets.Button(description='4')
button_5 = widgets.Button(description='5')
button_6 = widgets.Button(description='6', disabled = True)
button_7 = widgets.Button(description='7')
button_8 = widgets.Button(description='8', disabled = True)
button_9 = widgets.Button(description='9')
button_ENTER = widgets.Button(description= 'ENTER', button_style = 'success')
button_ENTER.style.button_colour = 'LimeGreen'
button_BACK = widgets.Button(description='<--')
button_CLEAR = widgets.Button(description='CLEAR')
text = widgets.Text()
row1 = ipywidgets.HBox([button_0,
        button_1,
        button_2,
        button_3,
        button_4,
        button_5,
        button_6,
        button_7,
        button_8,
        button_9
        ])
row2 = ipywidgets.HBox([button_A,
        button_B,
        button_C,
        button_D,
        button_E,
        button_F,
        button_G,
        button_H,
        button_I,
        button_J
        ])
row3 = ipywidgets.HBox([button_K,
        button_L,
        button_M,
        button_N,
        button_O,
        button_P,
        button_Q,
        button_R,
        button_S,
        button_T
        ])
row4 = ipywidgets.HBox([button_U,
        button_V,
        button_W,
        button_X,
        button_Y,
        button_Z,
        button_CLEAR,
        button_BACK,
        button_SPACE,
        button_ENTER
        ])
disp = ipywidgets.VBox([row1,row2,row3,row4,text])

def btn_eventhandler(obj):
    if(str(obj.description)=='[__]'):
        text.value = text.value + ' '
    elif(str(obj.description)=='CLEAR'):
        text.value = ''
    elif(str(obj.description)=='<--'):
        text.value = str(text.value)[:len(str(text.value))-1]
    elif(str(obj.description)=='ENTER'):
        draw(str(text.value))
        text.value = ''
    else:
        text.value = text.value + str(obj.description)
button_A.on_click(btn_eventhandler)
button_B.on_click(btn_eventhandler)
button_C.on_click(btn_eventhandler)
button_D.on_click(btn_eventhandler)
button_E.on_click(btn_eventhandler)
button_F.on_click(btn_eventhandler)
button_G.on_click(btn_eventhandler)
button_H.on_click(btn_eventhandler)
button_I.on_click(btn_eventhandler)
button_J.on_click(btn_eventhandler)
button_K.on_click(btn_eventhandler)
button_L.on_click(btn_eventhandler)
button_M.on_click(btn_eventhandler)
button_N.on_click(btn_eventhandler)
button_O.on_click(btn_eventhandler)
button_P.on_click(btn_eventhandler)
button_Q.on_click(btn_eventhandler)
button_R.on_click(btn_eventhandler)
button_S.on_click(btn_eventhandler)
button_T.on_click(btn_eventhandler)
button_U.on_click(btn_eventhandler)
button_V.on_click(btn_eventhandler)
button_W.on_click(btn_eventhandler)
button_X.on_click(btn_eventhandler)
button_Y.on_click(btn_eventhandler)
button_Z.on_click(btn_eventhandler)
button_0.on_click(btn_eventhandler)
button_1.on_click(btn_eventhandler)
button_2.on_click(btn_eventhandler)
button_3.on_click(btn_eventhandler)
button_4.on_click(btn_eventhandler)
button_5.on_click(btn_eventhandler)
button_6.on_click(btn_eventhandler)
button_7.on_click(btn_eventhandler)
button_8.on_click(btn_eventhandler)
button_9.on_click(btn_eventhandler)
button_SPACE.on_click(btn_eventhandler)
button_CLEAR.on_click(btn_eventhandler)
button_BACK.on_click(btn_eventhandler)
button_ENTER.on_click(btn_eventhandler)

# %%
display(disp)

# %%
draw('0')
